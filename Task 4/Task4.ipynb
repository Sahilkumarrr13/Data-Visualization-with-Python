# %% [markdown]
# # Plotting using seaborn:

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path = r"E:\Data Visualisation Python Project\birthYearly.csv"
df = pd.read_csv(path)
df
# Out:
#         month  year  births
# 0     January  2000     101
# 1    February  2000     168
# 2       March  2000     271
# 3       April  2000     229
# 4         May  2000     287
# ..        ...   ...     ...
# 79     August  2006     243
# 80  September  2006     174
# 81    October  2006      62
# 82   November  2006     175
# 83   December  2006     134
#
# [84 rows x 3 columns]

# %% [markdown]
# We will be using heatmaps for this task:

# %% [markdown]
# Heatmaps are popularly used to spotting small and large changes between vairables.
# They need to be sometimes be plotted with pivot table

# %%
sns.heatmap(df, annot=True, fmt='d')
#annt is used to define it we want to see number in color and fmt is used to declare format
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [15], in <cell line: 1>()
# ----> 1 sns.heatmap(df, annot=True, fmt='d')
#
# File C:\Anaconda\lib\site-packages\seaborn\_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# File C:\Anaconda\lib\site-packages\seaborn\matrix.py:540, in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
# ...

# %% [markdown]
# As we can clearly see there is an error in the data. This is because the month count is in the form of string <br />
# Therefore we need to sometimes <b> format our data in a form of pivot </b>

# %%
df_pivot = df.pivot("month", "year", "births")
df_pivot
# Out:
# year       2000  2001  2002  2003  2004  2005  2006
# month
# April       229    75   289   214   261   115   299
# August      238   162    86    97   202   158   243
# December    152   286   175   142    58   269   134
# February    168    64   152    71   285   242   201
# January     101   291   274    70    84   279   299
# July        142   285   125   194    77   235   193
# June        183   112   257   103   199   204   136
# March       271   289   248    54    70   258   196
# May         287   141   112   258   175   125    70
# November    108    69   131   152    99   230   175
# October     263   148   274   235   157   224    62
# September   264    96   123   104    53   225   174

# %%
sns.set(rc={'figure.figsize':(12,9)})
sns.heatmap(df_pivot, annot = True, fmt = 'd')
plt.show()

# %% [markdown]
# We can see how beautifully seaborn presented us the data in visual forms using colors. We can easily look at small and large number. For eg- We can say that <b> March 2003, September 2004, December 2004 has small number of births </b> and on the other hand <b> April 2006, January 2006 showed large number of births </b>

# %% [markdown]
# ### We can even change the color of heatmap using <code>cmap</code>:

# %%
sns.set(rc={'figure.figsize':(12,9)})
sns.heatmap(df_pivot, annot = True, fmt = 'd', cmap="RdBu")
plt.show()

# %%
sns.set(rc={'figure.figsize':(12,9)})
sns.heatmap(df_pivot, annot = True, fmt = 'd', cmap="Blues")
plt.show()

# %%
sns.set(rc={'figure.figsize':(12,9)})
sns.heatmap(df_pivot, annot = True, fmt = 'd', cmap="Greens")
plt.show()

# %%
sns.set(rc={'figure.figsize':(12,9)})
sns.heatmap(df_pivot, annot = True, fmt = 'd', cmap="YlGnBu")
plt.show()
